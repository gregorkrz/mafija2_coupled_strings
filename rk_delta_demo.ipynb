# %%
from lib import save_animation, integrate_rk_delta, domain, get_derivative_matrix, initial_gauss
import numpy as np

# %%
n_space_pts = 1000
x, l, m, r = domain(n_space_pts, d=100)
y = np.zeros((len(x), 2))
y[:, 0] = initial_gauss(x, l, premik=-25)
y1 = np.zeros((len(x), 2))

# %%
zg_resitev, sp_resitev, t = integrate_rk_delta(y, y1, (x,l,m,r), get_derivative_matrix(2*n_space_pts+1), Qu=1, Qv=1, T=150, n_steps=3000, mu=1.)
save_animation(x, zg_resitev, sp_resitev, t, 'test_delta.gif')
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# Saving animation...
# Done - animation saved to test_delta.gif
